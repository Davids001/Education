# %%
import pandas as pd
solar_data = pd.read_csv('solarpower.csv')
solar_data.head()
# Out:
#          date  cum_power
# 0  2017-01-01    20111.0
# 1  2017-01-02    20112.0
# 2  2017-01-03    20115.0
# 3  2017-01-04    20117.0
# 4  2017-01-05    20119.0

# %%
for i in range(len(solar_data['cum_power'])):
    if solar_data['cum_power'][i] ==  -1:
        solar_data['cum_power'][i] = solar_data['cum_power'].diff().mean()
for i in solar_data['cum_power']:
    if i == -1:
        print('a')
# Out:
# /tmp/ipykernel_460782/2155146693.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_data['cum_power'][i] = solar_data['cum_power'].diff().mean()
# /tmp/ipykernel_460782/2155146693.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_data['cum_power'][i] = solar_data['cum_power'].diff().mean()

# %%
round(solar_data['cum_power'].mean(),)
# Out:
# 23776

# %%
solar_data['day_power'] = solar_data['cum_power'].diff()
solar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       664 non-null    object
#  1   cum_power  664 non-null    float64
#  2   day_power  663 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 15.7+ KB

# %%
solar_data['date'] = pd.to_datetime(solar_data['date']).dt.to_period('M')

# %%
.interpolate()

# %%
solar_data
# Out:
#         date  cum_power  day_power
# 0    2017-01    20111.0        NaN
# 1    2017-01    20112.0        1.0
# 2    2017-01    20115.0        3.0
# 3    2017-01    20117.0        2.0
# 4    2017-01    20119.0        2.0
# ..       ...        ...        ...
# 659  2018-10    28101.0        6.0
# 660  2018-10    28109.0        8.0
# 661  2018-10    28115.0        6.0
# 662  2018-10    28117.0        2.0
# 663  2018-10    28120.0        3.0
#
# [664 rows x 3 columns]

# %%
zen = solar_data.groupby('date',as_index=False)['day_power'].mean()
zen['day_power'] = zen['day_power'].round()

zen
# Out:
#        date  day_power
# 0   2017-01        3.0
# 1   2017-02        4.0
# 2   2017-03       11.0
# 3   2017-04       16.0
# 4   2017-05       19.0
# 5   2017-06       22.0
# 6   2017-07       18.0
# 7   2017-08       15.0
# 8   2017-09       12.0
# 9   2017-10        6.0
# 10  2017-11        3.0
# 11  2017-12        1.0
# 12  2018-01        2.0
# 13  2018-02        7.0
# 14  2018-03        9.0
# 15  2018-04       15.0
# 16  2018-05       21.0
# 17  2018-06       19.0
# 18  2018-07       22.0
# 19  2018-08       17.0
# 20  2018-09       14.0
# 21  2018-10        9.0

# %%
import plotly
import plotly.express as px
fig =px.line(
    data_frame=solar_data,
    x='date',
    y ='day_power',
    );
fig.show()

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame(dict(
    x = [1, 3, 2, 4],
    y = [1, 2, 3, 4]
))
display(df)
fig = px.line(df, x="x", y="y", title="Unsorted Input") 
fig.show()
# Out:
#    x  y
# 0  1  1
# 1  3  2
# 2  2  3
# 3  4  4
